# %%
#data
import pandas as pd

#visualization
from matplotlib import pyplot as plt
import seaborn as sns
from matplotlib import rcParams
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv("HomeworkDataset.csv",encoding='latin1')

# %%
dataset.head()
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22/05/2015  Buena Vista Studios                  202.1           170.0
# 1   14/03/2014  Buena Vista Studios                  204.2            66.0
# 2   15/08/2014            Lionsgate                  207.1           100.0
# 3   16/03/2012                 Sony                  208.8            42.0
# 4   28/06/2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# ...

# %%
dataset.columns = ['DayOfWeek', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate',
       'Studio', 'Adjusted Gross$Millions', 'Budget$Millions', 'Gross$Millions',
       'IMDbRating', 'MovieLensRating', 'Overseas$Millions', 'Overseas%',
       'Profit$Millions', 'Profit%', 'RuntimeMinutes', 'US$Millions',
       'Gross%US']

# %%
dataset
# Out:
#      DayOfWeek                                Director   Genre  \
# 0       Friday                               Brad Bird  action
# 1       Friday                             Scott Waugh  action
# 2       Friday                          Patrick Hughes  action
# 3       Friday                 Phil Lord, Chris Miller  comedy
# 4       Friday                         Roland Emmerich  action
# ..         ...                                     ...     ...
# 603  Wednesday                        William Friedkin  horror
# 604  Wednesday                            George Lucas  action
# 605     Friday                           James Cameron  sci-fi
# 606  Wednesday                           James Cameron   drama
# 607     Friday  George Cukor, Victor Fleming, Sam Wood   drama
#
#              MovieTitle ReleaseDate               Studio  \
# 0          Tomorrowland  22/05/2015  Buena Vista Studios
# 1        Need for Speed  14/03/2014  Buena Vista Studios
# ...

# %%
plot_data = dataset[dataset.Genre.isin(['action','comedy','adventure','animation','drama'])]
plot_data = plot_data[plot_data.Studio.isin(['Buena Vista Studios','Sony','Universal','WB','Paramount Pictures','Fox'])]
scatter_data = dataset[dataset.Studio.isin(['Buena Vista Studios','Sony','Universal','WB','Paramount Pictures','Fox'])]

plot_data.head()
# Out:
#   DayOfWeek                 Director   Genre        MovieTitle ReleaseDate  \
# 0    Friday                Brad Bird  action      Tomorrowland  22/05/2015
# 1    Friday              Scott Waugh  action    Need for Speed  14/03/2014
# 3    Friday  Phil Lord, Chris Miller  comedy    21 Jump Street  16/03/2012
# 4    Friday          Roland Emmerich  action  White House Down  28/06/2013
# 5    Friday               David Ayer  action              Fury  17/10/2014
#
#                 Studio Adjusted Gross$Millions  Budget$Millions  \
# 0  Buena Vista Studios                   202.1            170.0
# 1  Buena Vista Studios                   204.2             66.0
# 3                 Sony                   208.8             42.0
# 4                 Sony                   209.7            150.0
# 5                 Sony                   212.8             80.0
#
#   Gross$Millions  IMDbRating  MovieLensRating Overseas$Millions  Overseas%  \
# ...

# %%
sns.set_style("darkgrid")

sns.catplot(data=plot_data, x='Genre', y='Gross%US',hue='Studio', s=7,height=8.27, aspect=11.7/8.27)
sns.boxplot(data=plot_data,
            x='Genre', y='Gross%US', color="white" )
plt.ylabel("Gross % US", fontsize=35)
plt.xlabel("Genre", fontsize=35)
plt.title("Domestic Gross % by Genre", fontsize=35)


plt.show()
